# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('colheader_justify', 'center')
import numpy as np
import datetime, sys
import yfinance as yf

def eliminar_caracteres(cadena):
    caracteres_a_eliminar = ['\n', '\r', ' ', '%', '.']
    tabla_de_reemplazo = str.maketrans('', '', ''.join(caracteres_a_eliminar))
    return cadena.translate(tabla_de_reemplazo)

def clasify_number(num):
    if num//10**9>0:
        return str(round(num/10**9, 1))+'B'
    if num//10**6>0:
        return str(round(num/10**6, 1))+'M'
    if num//10**3>0:
        return str(round(num/10**3, 1))+'k'
    else:
        return str(round(num,1))
def clasify_numbers(numbers):
    return np.vectorize(clasify_number)(numbers)

def get_stock_price(symbols):
    def get_sck(s):
        Tk = yf.Ticker(s)
        try:
            p = Tk.history('1d')['Close'].iloc[-1]
        except:
            return np.nan
        return p

    if isinstance(symbols, (list, tuple, np.ndarray)):
        return np.array([get_sck(s) for s in symbols])
    return get_sck(symbols)

def get_table(url):
    response = requests.get(url)
    if response.status_code != 200:
        raise TimeoutError('La página está caida')

    if 'bonos' in url:
        c=-3 # ['Símbolo', 'ÚltimoOperado', 'VariaciónDiaria', 'CantidadCompra', 'PrecioCompra', 'PrecioVenta', 'CantidadVenta', 'Máximo', 'Mínimo', 'ÚltimoCierre', 'MontoOperado']
    elif 'cedears' in url:
        c=-1 # ['Símbolo', 'ÚltimoOperado', 'VariaciónDiaria', 'CantidadCompra', 'PrecioCompra', 'PrecioVenta', 'CantidadVenta', 'Apertura', 'Mínimo', 'Máximo', 'ÚltimoCierre', 'MontoOperado']
    elif 'estados-unidos' in url:
        c=2 # ['Símbolo', 'ÚltimoOperado']
    else:
        raise Error('no se reconoce la url proporcionada')

    page = BeautifulSoup(response.content, 'html.parser')
    html_table = page.find(id = 'cotizaciones')
    columnas = [i.text for i in html_table.find('thead').find('tr').find_all('td')[:c]]

    assets = html_table.find('tbody').find_all('tr')

    assets_df = pd.DataFrame(columns=columnas)

    for asset in assets:
        asset = asset.find_all('td')[:c] # valores correspondientes a las columnas ['Símbolo', 'ÚltimoOperado', ...]
        symbol = eliminar_caracteres(asset[0].find('b').text)
        name = eliminar_caracteres(asset[0].find('span').text)
        asset = pd.Series([symbol] + [eliminar_caracteres(td.text).replace(',','.') for td in asset[1:]], columnas)
        asset[asset=='-']=np.nan
        if c!=-3: asset['name'] = name.lower()
        assets_df = assets_df._append(asset, ignore_index=True)

    assets_df['ÚltimoOperado'] = assets_df['ÚltimoOperado'].astype(float)
    if c == 2:
        return assets_df

    assets_df['VariaciónDiaria'] = assets_df['VariaciónDiaria'].astype(float)
    assets_df['CantidadCompra'] = assets_df['CantidadCompra'].astype(float)
    assets_df['PrecioCompra'] = assets_df['PrecioCompra'].astype(float)
    assets_df['PrecioVenta'] = assets_df['PrecioVenta'].astype(float)
    assets_df['CantidadVenta'] = assets_df['CantidadCompra'].astype(float)
    assets_df['Máximo'] = assets_df['Máximo'].astype(float)
    assets_df['Mínimo'] = assets_df['Mínimo'].astype(float)
    assets_df['ÚltimoCierre']= assets_df['ÚltimoCierre'].astype(float)
    assets_df['MontoOperado'] = assets_df['MontoOperado'].astype(float)

    if c == -1:
        assets_df['Apertura'] = assets_df['Apertura'].astype(float)
    return assets_df

# %% [markdown]
# ## Bonos Argentinos
# Obtenemos las cotizaciones de los Bonos en ARS y en USD (símbolos terminados en 'D'), luego estimamos el valor del dólar MEP a partir de dichas cotizaciones. Coomo cotizaciones se toma el último valor operado brindado por 'InvertirOnline' en su página pública de cotizaciones (nota: estas se actualizan cada 20 min, no están en tiempo real).

# %%
bonos = get_table('https://iol.invertironline.com/mercado/cotizaciones/argentina/bonos/soberanos-en-dólares')

# separamos los bonos en pesos y los bonos en dólares
bonos_ARS = bonos[~(bonos['Símbolo'].str.endswith('D') | bonos['Símbolo'].str.endswith('C'))]
bonos_MEP = bonos[bonos['Símbolo'].str.endswith('D')]

# filtramos todos los bonos que tienen cotización en pesos y en dólares a la vez
bonos_ARS = bonos_ARS[(bonos_ARS['Símbolo']+'D').isin(bonos_MEP['Símbolo'])].sort_values(by='Símbolo')
bonos_MEP = bonos_MEP[bonos_MEP['Símbolo'].isin(bonos_ARS['Símbolo']+'D')].sort_values(by='Símbolo')

cols = ['MEP', 'Vol. ARS', 'Vol. USD']
bonos = pd.DataFrame(index=bonos_ARS['Símbolo'], columns=cols)
bonos[cols[0]] = (bonos_ARS['ÚltimoOperado'].values/bonos_MEP['ÚltimoOperado'].values).round(2)
bonos[cols[1]] = clasify_numbers(bonos_ARS['MontoOperado'].values)
bonos[cols[2]] = clasify_numbers(bonos_MEP['MontoOperado'].values)

bonos_filt = bonos[(bonos_ARS['MontoOperado'].values>0) & (bonos_MEP['MontoOperado'].values>0)].sort_values(by='MEP', ascending=True)
if bonos_filt.shape[0]==0:
    print('No hay suficiente volumen operado')
bonos_filt
# Out:
#            MEP  Vol. ARS Vol. USD
# Símbolo
# GD38     590.55    1.2B    84.7k
# AL35     602.88  158.2M    66.5k
# GD35     606.15    2.9B    74.5k
# GD46     611.23   43.1M     1.5k
# CO26     616.67   83.4M    38.1k
# GD30     621.14   22.3B     9.5M
# GD41     621.21  359.7M     5.7k
# AL29     629.00  191.0M    38.0k
# AE38     634.44  280.2M    91.5k
# AL30     636.84   35.9B    21.9M
# GD29     639.67   17.5M     8.2k
# AL41     639.76   29.0M    31.6k

# %%
cedears = get_table('https://iol.invertironline.com/mercado/cotizaciones/argentina/cedears/todos')

# separamos los bonos en pesos, filtrando por el nombre de la compañía.
cedears_ARS = cedears.drop_duplicates(subset='name')
filt = {'ADGO':'ARGO','AKOB':0,'AOCAD':0,'ARKKETF':0,'AUY':0,'BBV':'BBVA','BNG':'BG','BRKB':0,'CS':0,'DISN':'DIS','GOGLD':0,'MAD':0,'NOKA':'NOK','OGZD':0,'PKS':'PKX','SI':0,'TEFO':'TEF','TEN':'TS','TWTR':0,'TXR':'TX','XROX':'XRX'}

# eliminamos los cedears que no aparecen en yahoo_finance
eliminar = list(filter(lambda clave: filt[clave] == 0, filt.keys()))
cedears_ARS = cedears_ARS[~cedears_ARS['Símbolo'].isin( eliminar )]

cedears_MEP = cedears[(cedears['name'].isin(cedears_ARS['name']) & cedears['Símbolo'].str.endswith('D') & ~cedears['Símbolo'].isin(cedears_ARS['Símbolo']))]
cedears_ARS = cedears_ARS[cedears_ARS['name'].isin(cedears_MEP['name'])]

cedears_ARS = cedears_ARS.sort_values(by='Símbolo')
cedears_MEP = cedears_MEP.sort_values(by='Símbolo', key=lambda x: x.map({v: i for i, v in enumerate((cedears_ARS['Símbolo']+'D').values)}))

cols = ['Símbolo', 'Precio[ARS]', 'Volumen[ARS]', 'Precio[USD]', 'Volumen[USD]', 'USD_MEP', 'Cedear[USD]', 'Acción[USD]','ratio[Ced/Acc-1]%','Compañía']
cedears = pd.DataFrame(columns=cols)

cedears['Símbolo'] = cedears_ARS['Símbolo'].values
cedears['Precio[ARS]'] = cedears_ARS['ÚltimoOperado'].values
cedears['Volumen[ARS]'] = clasify_numbers(cedears_ARS['MontoOperado'].values)
cedears['Precio[USD]'] = cedears_MEP['ÚltimoOperado'].values
cedears['Volumen[USD]'] = clasify_numbers(cedears_MEP['MontoOperado'].values)
cedears['USD_MEP'] = (cedears_ARS['ÚltimoOperado'].values/cedears_MEP['ÚltimoOperado'].values).round(1)

# modificamos los símbolos para que coincidan con yahoo_finance
modificar = list(filter(lambda clave: filt[clave] != 0, filt.keys()))
new_ARS = list(filter(lambda valor: valor != 0, filt.values()))
cedears['Símbolo'] = cedears['Símbolo'].replace(modificar, new_ARS)
cedears = cedears.set_index('Símbolo').sort_index()

ratio = pd.read_json('ratios.json', orient='index').sort_index(); ratio.columns = ['ratio']
cedears['Cedear[USD]'] = (ratio['ratio'].values * cedears['Precio[USD]'].values).round(2)
cedears['Acción[USD]'] = get_stock_price(cedears.index.values).round(2) # Obtiene los valores de las
cedears['ratio[Ced/Acc-1]%'] = (100 * (cedears['Cedear[USD]'].values/cedears['Acción[USD]'].values - 1)).round(1)
cedears['Compañía'] = cedears_ARS['name'].values
cedears[(cedears_ARS['MontoOperado'].values>=0) & (cedears_MEP['MontoOperado'].values>=0)].sort_values(by='USD_MEP')
# Out:
#          Precio[ARS] Volumen[ARS]  Precio[USD] Volumen[USD]  USD_MEP  \
# Símbolo
# FMX        12267.5        2.5M        39.50          0.0      310.6
# UNH        10101.5       24.0M        19.80        564.0      510.2
# BIDU        8167.5       24.1M        15.70          0.0      520.2
# ZM           932.5        3.7M         1.79          0.0      520.9
# PG         20413.0       18.4M        37.90        369.0      538.6
# SNOW        3340.0        7.0M         6.15          0.0      543.1
# MMM        13556.5       12.2M        24.85         4.0k      545.5
# NEM         8625.5        1.8M        15.80          0.0      545.9
# GSK         5793.5        2.3M        10.60         53.0      546.6
# SHOP         343.5       37.1M         0.61        768.0      563.1
# BP          4799.5        2.6M         8.50        584.0      564.6
# MO          7148.0       20.3M        12.65         6.1k      565.1
# CVX        13427.5       40.7M        23.50         7.6k      571.4
# TM         21881.0        3.6M        38.00        728.0      575.8
# JNJ         7572.5      165.7M        13.15         6.4k      575.9
# WFC         5723.0       28.0M         9.90          0.0      578.1
# FDX        17357.0      483.9k        30.00          0.0      578.6
# VZ         10997.0       28.7M        19.00        724.0      578.8
# AMX        12470.0        2.8M        21.50          0.0      580.0
# PYPL        5181.0      223.0M         8.89         6.7k      582.8
# HMY         2521.0       28.2M         4.32        488.0      583.6
# GS         17100.0        1.3M        29.20          0.0      585.6
# VALE        4100.0      156.0M         6.98         4.7k      587.4
# SPOT        3250.5       33.7M         5.50          0.0      591.0
# AXP         7249.5       13.5M        12.25         98.0      591.8
# RIO         9808.0      147.2M        16.50        343.0      594.4
# MCD         7883.5       49.3M        13.25        12.3k      595.0
# ITUB        3594.0        6.0M         6.00          6.0      599.0
# DOCU        1450.0       14.3M         2.42          0.0      599.2
# PBR         8848.5      121.6M        14.75         4.0k      599.9
# X           6782.5      829.2M        11.30        23.0k      600.2
# DESP        5412.0       29.7M         9.00         18.0      601.3
# ABT        17440.0        3.4M        29.00        261.0      601.4
# BBD         1990.5       56.2M         3.29        124.0      605.0
# MELI       14176.0      665.0M        23.40        37.4k      605.8
# DIS         4847.5      496.5M         8.00        10.4k      605.9
# NVDA       11945.0      249.5M        19.70        14.0k      606.3
# V           8825.5       27.0M        14.50         3.5k      608.7
# VIST       16750.0      886.4M        27.50        12.3k      609.1
# PFE        11817.5      115.1M        19.40         3.5k      609.1
# AVGO       14381.5        5.1M        23.50          0.0      612.0
# ERJ         9610.0       16.4M        15.70          0.0      612.1
# TS         22040.0      209.7M        36.00        464.0      612.2
# CAT         9310.5       21.6M        15.20          0.0      612.5
# JPM        20233.5       61.4M        33.00        569.0      613.1
# BABA        6808.5      372.0M        11.10         3.3k      613.4
# MSFT        7066.0      291.0M        11.50         8.5k      614.4
# NVS        16900.0      267.6k        27.50          0.0      614.5
# GLOB        6392.5      116.8M        10.40        222.0      614.7
# BIOX       15414.0       17.4M        25.05          0.0      615.3
# AAPL       11734.0      901.9M        19.00        45.5k      617.6
# INTC        4674.5       47.9M         7.54         2.0k      620.0
# TSLA       10454.0      397.3M        16.85        23.1k      620.4
# BAC        10118.5       39.3M        16.30        570.0      620.8
# AMD         7332.0      108.6M        11.80         2.4k      621.4
# T           3108.5       38.6M         5.00        775.0      621.7
# GILD       12997.0        1.6M        20.90        288.0      621.9
# C           9642.5       88.4M        15.50         92.0      622.1
# LMT        14703.0       10.0M        23.60          0.0      623.0
# ETSY        3241.0       16.6M         5.20          0.0      623.3
# GOLD       10917.0      142.9M        17.50        15.6k      623.8
# ABBV        9961.5        7.2M        15.95        177.0      624.5
# BA         25823.5       56.1M        41.35         3.9k      624.5
# AMZN         638.5      243.4M         1.02         8.5k      626.0
# IBM        18607.0       18.6M        29.70         1.3k      626.5
# QCOM        6770.0       66.2M        10.80        575.0      626.9
# CSCO        7056.5       21.2M        11.25        262.0      627.2
# AZN        23217.5       74.0M        37.00        111.0      627.5
# XOM        14670.0       74.6M        23.35         4.6k      628.3
# SQ          1966.5       18.4M         3.13         82.0      628.3
# NFLX       17450.5       49.5M        27.75        958.0      628.8
# NKE         5880.5       34.4M         9.35        906.0      628.9
# KO          7976.0        1.4B        12.65       226.5k      630.5
# TX         13236.0       41.0M        20.80          0.0      636.3
# WMT        17435.0      116.0M        27.35         2.4k      637.5
# META        8351.5      186.9M        13.10        12.1k      637.5
# MRK        14275.5        5.0M        22.20          0.0      643.0
# PSX        12569.0      300.9k        19.50          0.0      644.6
# EBAY       14387.0        5.5M        22.25          0.0      646.6
# SLB        13018.0        1.3M        19.90          0.0      654.2
# EFX         8006.5        3.8M        11.35          0.0      705.4
# UNP         7477.0      711.5k        10.20          0.0      733.0
# HWM        32450.0      772.3k        42.55          0.0      762.6
# CAH        20436.0        3.6M        17.60          0.0     1161.1
#
#          Cedear[USD]  Acción[USD]  ratio[Ced/Acc-1]%      Compañía
# Símbolo
# FMX         237.00       112.57          110.5                   femsa
# UNH         653.40       510.93           27.9          unitedhealthgr
# BIDU        172.70       137.59           25.5                   baidu
# ZM           84.13        67.55           24.5           zoomvideocomm
# PG          189.50       155.79           21.6          procter&gamble
# SNOW        184.50       152.86           20.7            snowflakeinc
# MMM         124.25       103.42           20.1                      3m
# NEM          47.40        39.46           20.1           newmontmining
# GSK          42.40        35.44           19.6         glaxosmithkline
# SHOP         65.27        55.98           16.6              shopifyinc
# BP           42.50        36.68           15.9                      bp
# MO           50.60        43.53           16.2             altriagroup
# CVX         188.00       164.03           14.6                 chevron
# TM          190.00       166.70           14.0                 tenaris
# JNJ         197.25       173.44           13.7         johnson&johnson
# WFC          49.50        43.74           13.2              wellsfargo
# FDX         300.00       266.94           12.4                   fedex
# VZ           38.00        33.56           13.2          verizoncommuni
# AMX          21.50        19.00           13.2            americamovil
# PYPL         71.12        63.27           12.4          paypalholdings
# HMY           4.32         3.87           11.6             harmonygold
# GS          379.60       337.74           12.4            goldmansachs
# VALE         13.96        12.47           11.9                    vale
# SPOT        154.00       139.38           10.5          spotifytechnol
# AXP         183.75       166.08           10.6         americanexpress
# RIO          66.00        59.94           10.1                riotinto
# MCD         318.00       288.81           10.1              mcdonald's
# ITUB          6.00         5.45           10.1           bancoitaúunib
# DOCU         53.24        49.43            7.7             docusigninc
# PBR          14.75        13.50            9.3          petroleobrasil
# X            33.90        31.08            9.1           unitedstatess
# DESP          9.00         8.24            9.2                despegar
# ABT         116.00       106.10            9.3          abbottlaborato
# BBD           3.29         3.05            7.9           bancobradesco
# MELI       1404.00      1296.52            8.3            mercadolibre
# DIS          96.00        88.81            8.1           thewaltdisney
# NVDA        472.80       437.53            8.1                  nvidia
# V           261.00       242.90            7.5                    visa
# VIST         27.50        25.49            7.9            vistaenergys
# PFE          38.80        36.07            7.6                  pfizer
# AVGO        916.50       854.10            7.3             broadcominc
# ERJ          15.70        14.68            6.9               embraersa
# TS           36.00        33.63            7.0            toyotamotors
# CAT         304.00       284.54            6.8             caterpillar
# JPM         165.00       154.77            6.6           jpmorganchase
# BABA         99.90        93.46            6.9            alibabagroup
# MSFT        345.00       324.04            6.5               microsoft
# NVS         110.00       103.37            6.4              novartisag
# GLOB        187.20       175.70            6.5                 globant
# BIOX         12.52        11.81            6.0           biocerescrops
# AAPL        190.00       179.46            5.9                   apple
# INTC         37.70        35.68            5.7                   intel
# TSLA        252.75       239.76            5.4                   tesla
# BAC          32.60        30.93            5.4           bankofamerica
# AMD         118.00       111.98            5.4           advancedmicro
# T            15.00        14.26            5.2                    at&t
# GILD         83.60        79.85            4.7          gileadsciences
# C            46.50        44.10            5.4               citigroup
# LMT         472.00       450.08            4.9          lockheedmartin
# ETSY         83.20        79.30            4.9                 etsyinc
# GOLD         17.50        16.67            5.0             barrickgold
# ABBV        159.50       152.27            4.7               abbvieinc
# BA          248.10       236.71            4.8                  boeing
# AMZN        146.88       140.57            4.5                  amazon
# IBM         148.50       141.91            4.6                     ibm
# QCOM        118.80       114.02            4.2                qualcomm
# CSCO         56.25        53.88            4.4            ciscosystems
# AZN          74.00        70.84            4.5             astrazeneca
# XOM         116.75       111.92            4.3              exxonmobil
# SQ           62.60        60.15            4.1               squareinc
# NFLX        444.00       427.78            3.8                 netflix
# NKE         112.20       107.64            4.2                    nike
# KO           63.25        60.88            3.9           thecoca-colac
# TX           41.60        40.21            3.5                 ternium
# WMT         164.10       160.00            2.6                 walmart
# META        314.40       306.19            2.7        metaplatformsinc
# MRK         111.00       108.91            1.9                   merck
# PSX         117.00       114.67            2.0              phillips66
# EBAY         44.50        44.03            1.1                    ebay
# SLB          59.70        59.52            0.3            schlumberger
# EFX         181.60       196.72           -7.7              equifaxinc
# UNP         204.00       229.80          -11.2           unionpacificc
# HWM          42.55        49.22          -13.6         howmetaerospace
# CAH          52.80        92.99          -43.2          cardinalhealth
